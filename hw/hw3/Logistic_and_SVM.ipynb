# %% [markdown]
# <a class="anchor" id="0"></a>
# # **Home Work 3: Logistic regression and SVM**

# %% [markdown]
# ### 제출마감: 5월 9일
# ### 배점: 5점
#
# The Fish data set has 7 features: Species, Weight, Length1, Length2, Length3, Height, and Width.
#
# Write a python code to predict the ‘Species’ based on the rest of the features. Species is a multi-class categorical variable holding the labels ‘Bream’, ‘Roach’, ‘Whitefish’, ‘Parkki’, ‘Perch’, ‘Pike’, ‘Smelt’.
#
# - You must use **train_test_split function with test_size= 0.2, random_state=2022.**
# - Specify **train accuracy and test accuracy.**

# %% [markdown]
# # 1. with Logistic Regression

# %% [markdown]
# # 2. with SVM
